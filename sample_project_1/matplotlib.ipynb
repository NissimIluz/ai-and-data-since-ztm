# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y)

# %%
# 1st method 
fig = plt.figure() # create a figure
ax = fig.add_subplot() # adds some axes
ax.plot(x,y)
fig.show()
# Out:
# C:\Users\eiloz\AppData\Local\Temp\ipykernel_17856\1910624116.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# 2st method 
fig = plt.figure() # create a figure
ax = fig.add_axes([1,1,1,1]) # adds some axes
ax.plot(x,y)
fig.show()
# Out:
# C:\Users\eiloz\AppData\Local\Temp\ipykernel_17856\940516508.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# 3st method 0 recommanded
fig, ax = plt.subplots() # create a figure
ax.plot(x,y)
fig.show()
# Out:
# C:\Users\eiloz\AppData\Local\Temp\ipykernel_17856\17097553.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# # Matplotlib example worlflow

# %%
# 1. Prepare data
x = [1,2,3,4]
y = [11, 22 ,33 ,44]

# 2. Serup data
fig, ax = plt.subplots(figsize=(10,10))

# 3. Plot data
ax.plot(x,y)

# 4. Customize plot
ax.set(title = "Simple Plot", xlabel="x-axis", ylabel="y-axis")

# 5. Save & sow (you save to whole figure)
fig.savefig("images/sample-plot-fix.png")

# %% [markdown]
# ## Making figures with NumPy arrays

# %%
# Create some data
x = np.linspace(0,10,100)

# plot the d
fix, ax = plt.subplots()
ax.plot(x, x**2)

# %%
# scatter plot
fix, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another scatter plot 
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from dictionary
nut_butter_prices = {
    "Almond Butter": 12.99,
    "Peanut Butter": 5.49,
    "Cashew Butter": 10.99,
    "Hazelnut Butter": 14.99,
    "Sunflower Butter": 7.99
}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title="nut_butter_prices", ylabel="price" )
# Out:
# [Text(0.5, 1.0, 'nut_butter_prices'), Text(0, 0.5, 'price')]

# %%
fix, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# Make some data
x = np.random.randn(1000000)

fix, ax = plt.subplots()

ax.hist(x)
# Out:
# (array([8.40000e+01, 3.10300e+03, 4.24710e+04, 2.10469e+05, 3.90464e+05,
#         2.73994e+05, 7.21150e+04, 7.02600e+03, 2.71000e+02, 3.00000e+00]),
#  array([-4.78724546, -3.75431578, -2.7213861 , -1.68845643, -0.65552675,
#          0.37740293,  1.41033261,  2.44326228,  3.47619196,  4.50912164,
#          5.54205131]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Two options for subplots

# %%
# Subplot option 1
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10,5))

ax0.plot(x, x/2)
ax1.scatter(np.random.random(10),np.random.random(10))
ax2.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax3.hist(np.random.randn(1000000))
# Out:
# (array([4.40000e+01, 1.96700e+03, 2.85580e+04, 1.61005e+05, 3.59277e+05,
#         3.19456e+05, 1.12871e+05, 1.59550e+04, 8.44000e+02, 2.30000e+01]),
#  array([-4.87237665, -3.87252775, -2.87267884, -1.87282993, -0.87298103,
#          0.12686788,  1.12671679,  2.12656569,  3.1264146 ,  4.12626351,
#          5.12611241]),
#  <BarContainer object of 10 artists>)

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,
                        ncols=2,
                        figsize=(20,15))
ax[0,0].plot(x, x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000000))
# Out:
# (array([4.20000e+01, 1.41000e+03, 1.97230e+04, 1.19049e+05, 3.07658e+05,
#         3.45328e+05, 1.68132e+05, 3.52860e+04, 3.23700e+03, 1.35000e+02]),
#  array([-4.87150414, -3.92327506, -2.97504598, -2.0268169 , -1.07858782,
#         -0.13035874,  0.81787034,  1.76609942,  2.7143285 ,  3.66255758,
#          4.61078666]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Plotting frm pandas DataFrames

# %%
# Make a dataframe
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range('1/1/2020', periods=1000))
ts = ts.cumsum()

ts.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 ts = pd.Series(np.random.randn(1000),
#       2                index=pd.date_range('1/1/2020', periods=10))
#       3 ts = ts.cumsum()
#       5 ts.plot()
#
# File C:\projects\sample_project_1\env\Lib\site-packages\pandas\core\series.py:575, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     573     index = default_index(len(data))
#     574 elif is_list_like(data):
# --> 575     com.require_length_match(data, index)
#     577 # create/copy the manager
#     578 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File C:\projects\sample_project_1\env\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# ...

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$,\.]', '', regex=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price    price
# 0  Toyota  White         150043      4   $4,000.00   400000
# 1   Honda    Red          87899      4   $5,000.00   500000
# 2  Toyota   Blue          32549      3   $7,000.00   700000
# 3     BMW  Black          11179      5  $22,000.00  2200000
# 4  Nissan  White         213095      4   $3,500.00   350000
# 5  Toyota  Green          99213      4   $4,500.00   450000
# 6   Honda   Blue          45698      4   $7,500.00   750000
# 7   Honda   Blue          54738      4   $7,000.00   700000
# 8  Toyota  White          60000      4   $6,250.00   625000
# 9  Nissan  White          31600      4   $9,700.00   970000

# %%
car_sales["Sale date"] = pd.date_range("1/1/2020", periods=len(car_sales))

# %%
car_sales["Total Sales"] = car_sales["price"].astype(int).cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price    price  Sale_date  \
# 0  Toyota  White         150043      4   $4,000.00   400000 2020-01-01
# 1   Honda    Red          87899      4   $5,000.00   500000 2020-01-02
# 2  Toyota   Blue          32549      3   $7,000.00   700000 2020-01-03
# 3     BMW  Black          11179      5  $22,000.00  2200000 2020-01-04
# 4  Nissan  White         213095      4   $3,500.00   350000 2020-01-05
# 5  Toyota  Green          99213      4   $4,500.00   450000 2020-01-06
# 6   Honda   Blue          45698      4   $7,500.00   750000 2020-01-07
# 7   Honda   Blue          54738      4   $7,000.00   700000 2020-01-08
# 8  Toyota  White          60000      4   $6,250.00   625000 2020-01-09
# 9  Nissan  White          31600      4   $9,700.00   970000 2020-01-10
#
#    Total Sales
# 0       400000
# 1       900000
# 2      1600000
# 3      3800000
# 4      4150000
# 5      4600000
# 6      5350000
# 7      6050000
# 8      6675000
# 9      7645000

# %%
# let't plot the total sales
car_sales.plot(x="Sale date", y= "Total Sales")
# Out:
# <Axes: xlabel='Sale date'>

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)", y= "Price", kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
x = np.random.rand(10,4)

df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
car_sales.plot(
# Out:
#      Make Colour  Odometer (KM)  Doors    Price    price  Sale_date  \
# 0  Toyota  White         150043      4   400000   400000 2020-01-01
# 1   Honda    Red          87899      4   500000   500000 2020-01-02
# 2  Toyota   Blue          32549      3   700000   700000 2020-01-03
# 3     BMW  Black          11179      5  2200000  2200000 2020-01-04
# 4  Nissan  White         213095      4   350000   350000 2020-01-05
# 5  Toyota  Green          99213      4   450000   450000 2020-01-06
# 6   Honda   Blue          45698      4   750000   750000 2020-01-07
# 7   Honda   Blue          54738      4   700000   700000 2020-01-08
# 8  Toyota  White          60000      4   625000   625000 2020-01-09
# 9  Nissan  White          31600      4   970000   970000 2020-01-10
#
#    Total Sales  Sale date
# 0       400000 2020-01-01
# 1       900000 2020-01-02
# 2      1600000 2020-01-03
# 3      3800000 2020-01-04
# 4      4150000 2020-01-05
# 5      4600000 2020-01-06
# 6      5350000 2020-01-07
# ...

# %%
car_sales.plot(x="Make", y="Odometer (KM)")
# Out:
# <Axes: xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease = pd.read_csv("heart-disease.csv")

# %%
heart_disease["age"].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ## Which one should you use? (pyplot vs matplotlib OO method?)
# • When plotting something quickly, okay to use the pyplot method
#
# • When plotting something more advanced, use the OO method

# %%
over_50 = heart_disease[heart_disease["age"] > 50]

# %%
# pyplot method
over_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target",
            figsize=(10,6))
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
# OO method
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target",
             ax=ax)



ax.set_xlim([45,100])
# Out:
# (45.0, 100.0)

# %%
## OO method from scracth
fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart", xlabel="Age", ylabel="Cholestrol")


# Add a legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add horizontal line
ax.axhline(over_50["chol"].mean(), linestyle='--')

# %%
## OO method from scracth
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               figsize=(10,10),
                              sharex=True)

# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])

# Customize ax0
ax0.set(title="Heart disease and Cholestrol Levels", xlabel="Age", ylabel="Cholestrol")


# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add horizontal line to ax0
ax0.axhline(over_50["chol"].mean(), linestyle='--')




# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"])

# Customize ax1
ax1.set(title="Heart disease and Max Heart Rit", xlabel="Age", ylabel="thalach")


# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Max Heart Rite")

# Add horizontal line to ax1
ax1.axhline(over_50["thalach"].mean(), linestyle='--')

# Add a title to the figure
fig.suptitle("Heart disease Analysis", fontsize=16, fontweight="bold")

;
# Out:
# ''

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-v0_8-whitegrid")

# %%
car_sales.Price.plot()
# Out:
# <Axes: >

# %%
# Recreate the plot from above with custom x and y axis ranges
fig, (ax0, ax1) = plt.subplots(nrows=2, 
                               ncols=1, 
                               sharex=True, 
                               figsize=(10, 7))
scatter = ax0.scatter(over_50["age"], 
                      over_50["chol"], 
                      c=over_50["target"],
                      cmap='winter')
ax0.set(title="Heart Disease and Cholesterol Levels",
        ylabel="Cholesterol",
        xlim=[50, 80]) # set the x-axis ranges 

# Setup a mean line
ax0.axhline(y=over_50["chol"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax0.legend(*scatter.legend_elements(), title="Target")

# Axis 1, 1 (row 1, column 1)
scatter = ax1.scatter(over_50["age"], 
                      over_50["thalach"], 
                      c=over_50["target"],
                      cmap='winter')
ax1.set(title="Heart Disease and Max Heart Rate Levels",
        xlabel="Age",
        ylabel="Max Heart Rate",
        ylim=[60, 220]) # change the y-axis range

# Setup a mean line
ax1.axhline(y=over_50["thalach"].mean(), 
            color="r", 
            linestyle="--", 
            label="Average");
ax1.legend(*scatter.legend_elements(), 
           title="Target")

# Title the figure
fig.suptitle("Heart Disease Analysis", 
             fontsize=16, 
             fontweight="bold");
